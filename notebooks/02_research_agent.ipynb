# %% [markdown]
# 1. Drop a few .txt files in data/sources
# 2. Run research.run(state) to attach quotes
# 3. Show claim_graph snippet
# 4. Export JSON story map (outline + claims)

# %% [markdown]
# # Research Agent — Local Notes Placeholder

# %%
from storygraph.agents import research
from storygraph.router import Pipeline

pipe = Pipeline(seed=137)
s = pipe.state

s.premise = "Premise here"
s.venue = "Outside"

s = research.run(s)

s.claim_graph
